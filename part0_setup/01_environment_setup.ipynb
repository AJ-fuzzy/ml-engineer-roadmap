# %% [markdown]
# # 01 Environment Setup
#
# ## Objectives
# Set up and verify a reproducible Python environment for machine learning projects.
# This notebook ensures all core ML libraries are installed and working correctly.
#
# ## Key Concepts
# - Add theory notes here
#
# ## Implementation
# - Step-by-step coding sections
#
# ## Experiments
# - Try variations and improvements
#
# ## Notes
# - Observations, mistakes, lessons learned

# %%
import sys
import platform

print("Python version:")
print(sys.version)

print("\nPlatform:")
print(platform.platform())
# Out:
# Python version:
# 3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]
#
# Platform:
# Windows-10-10.0.26100-SP0

# %%
import numpy as np
import pandas as pd
import sklearn
import torch

print("NumPy version:", np.__version__)
print("Pandas version:", pd.__version__)
print("Scikit-learn version:", sklearn.__version__)
print("PyTorch version:", torch.__version__)
# Out:
# NumPy version: 2.1.1
# Pandas version: 2.2.2
# Scikit-learn version: 1.5.1
# PyTorch version: 2.4.1+cpu

# %%
if torch.cuda.is_available():
    print("CUDA is available 🚀")
    print("GPU:", torch.cuda.get_device_name(0))
else:
    print("CUDA is NOT available (using CPU)")
# Out:
# CUDA is NOT available (using CPU)
